# %%
import pandas as pd

# %%
df = pd.read_csv('../../car_price_linear_regression/car_price.csv')

# %%
df = df.iloc[2:38,:]

# %% [raw]
# There is function pd.DataFrame(data, columns=cols). If we have lists
# But if we have dict, i.e. {'col1': some_data1, 'col2': some_data2}, then pd.DataFrame(data)

# %%
df1.head(5)
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 2  BMW  1 Series  2011  premium unleaded (required)      300.0
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0
# 5  BMW  1 Series  2012  premium unleaded (required)      230.0
# 6  BMW  1 Series  2012  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
# 6               6.0            MANUAL  rear wheel drive              2.0
#
#            Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df.Make
# Out:
# 2               BMW
# 3               BMW
# 4               BMW
# 5               BMW
# 6               BMW
# 7               BMW
# 8               BMW
# 9               BMW
# 10              BMW
# 11              BMW
# 12              BMW
# 13              BMW
# 14              BMW
# 15              BMW
# 16              BMW
# 17             Audi
# 18             Audi
# 19             Audi
# 20             Audi
# 21             Audi
# 22             Audi
# 23             Audi
# 24             Audi
# 25             Audi
# 26             Audi
# 27             Audi
# 28             Audi
# 29             Audi
# 30             Audi
# 31             Audi
# 32             FIAT
# 33             FIAT
# 34             FIAT
# 35    Mercedes-Benz
# 36    Mercedes-Benz
# 37    Mercedes-Benz
# Name: Make, dtype: object

# %%
df['Make']
# Out:
# 2               BMW
# 3               BMW
# 4               BMW
# 5               BMW
# 6               BMW
# 7               BMW
# 8               BMW
# 9               BMW
# 10              BMW
# 11              BMW
# 12              BMW
# 13              BMW
# 14              BMW
# 15              BMW
# 16              BMW
# 17             Audi
# 18             Audi
# 19             Audi
# 20             Audi
# 21             Audi
# 22             Audi
# 23             Audi
# 24             Audi
# 25             Audi
# 26             Audi
# 27             Audi
# 28             Audi
# 29             Audi
# 30             Audi
# 31             Audi
# 32             FIAT
# 33             FIAT
# 34             FIAT
# 35    Mercedes-Benz
# 36    Mercedes-Benz
# 37    Mercedes-Benz
# Name: Make, dtype: object

# %%
df[['Make', 'Model', 'MSRP']]
# Out:
#           Make       Model   MSRP
# 0          BMW  1 Series M  46135
# 1          BMW    1 Series  40650
# 2          BMW    1 Series  36350
# 3          BMW    1 Series  29450
# 4          BMW    1 Series  34500
# ...        ...         ...    ...
# 11909    Acura         ZDX  46120
# 11910    Acura         ZDX  56670
# 11911    Acura         ZDX  50620
# 11912    Acura         ZDX  50920
# 11913  Lincoln      Zephyr  28995
#
# [11914 rows x 3 columns]

# %%
temp_df = df.iloc[1:4, :]
temp_df
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0
# 5  BMW  1 Series  2012  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 3  Luxury,Performance      Compact         Coupe           28        18
# 4              Luxury      Compact   Convertible           28        18
# 5  Luxury,Performance      Compact         Coupe           28        18
#
#    Popularity   MSRP
# 3        3916  29450
# 4        3916  34500
# 5        3916  31200

# %%
# manually create column
temp_df['id'] = [1, 2, 3]
temp_df
# Out:
# <ipython-input-24-42a1f835806c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['id'] = [1, 2, 3]
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0
# 5  BMW  1 Series  2012  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
#
# ...

# %%
# delete column
del temp_df['id']

# %% [markdown]
# # Index

# %%
df.index
# Out:
# RangeIndex(start=2, stop=38, step=1)

# %%
df.Make
# Out:
# 2               BMW
# 3               BMW
# 4               BMW
# 5               BMW
# 6               BMW
# 7               BMW
# 8               BMW
# 9               BMW
# 10              BMW
# 11              BMW
# 12              BMW
# 13              BMW
# 14              BMW
# 15              BMW
# 16              BMW
# 17             Audi
# 18             Audi
# 19             Audi
# 20             Audi
# 21             Audi
# 22             Audi
# 23             Audi
# 24             Audi
# 25             Audi
# 26             Audi
# 27             Audi
# 28             Audi
# 29             Audi
# 30             Audi
# 31             Audi
# 32             FIAT
# 33             FIAT
# 34             FIAT
# 35    Mercedes-Benz
# 36    Mercedes-Benz
# 37    Mercedes-Benz
# Name: Make, dtype: object

# %%
df.loc[3] # index 3
# Out:
# Make                                         BMW
# Model                                   1 Series
# Year                                        2011
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                  230.0
# Engine Cylinders                             6.0
# Transmission Type                         MANUAL
# Driven_Wheels                   rear wheel drive
# Number of Doors                              2.0
# Market Category               Luxury,Performance
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   28
# city mpg                                      18
# Popularity                                  3916
# MSRP                                       29450
# Name: 3, dtype: object

# %%
temp = df.iloc[1:3, :]
temp
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 3  Luxury,Performance      Compact         Coupe           28        18
# 4              Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# 3        3916  29450
# 4        3916  34500

# %%
temp.index = ['a', 'b']
temp
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# a  BMW  1 Series  2011  premium unleaded (required)      230.0
# b  BMW  1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# a               6.0            MANUAL  rear wheel drive              2.0
# b               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# a  Luxury,Performance      Compact         Coupe           28        18
# b              Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# a        3916  29450
# b        3916  34500

# %%
temp.iloc[1] # but still we can refer as number if use iloc
# Out:
# Make                                         BMW
# Model                                   1 Series
# Year                                        2011
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                  230.0
# Engine Cylinders                             6.0
# Transmission Type                         MANUAL
# Driven_Wheels                   rear wheel drive
# Number of Doors                              2.0
# Market Category                           Luxury
# Vehicle Size                             Compact
# Vehicle Style                        Convertible
# highway MPG                                   28
# city mpg                                      18
# Popularity                                  3916
# MSRP                                       34500
# Name: b, dtype: object

# %%
# we can come back to initial index
temp.reset_index()
# Out:
#   index Make     Model  Year             Engine Fuel Type  Engine HP  \
# 0     a  BMW  1 Series  2011  premium unleaded (required)      230.0
# 1     b  BMW  1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 0  Luxury,Performance      Compact         Coupe           28        18
# 1              Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# 0        3916  29450
# 1        3916  34500

# %%
# to drop that newly created index
temp.reset_index(drop=True)
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series  2011  premium unleaded (required)      230.0
# 1  BMW  1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 0  Luxury,Performance      Compact         Coupe           28        18
# 1              Luxury      Compact   Convertible           28        18
#
#    Popularity   MSRP
# 0        3916  29450
# 1        3916  34500

# %% [markdown]
# # Element-wise operations

# %%
df['Engine HP'] /100
# Out:
# 2     3.00
# 3     2.30
# 4     2.30
# 5     2.30
# 6     3.00
# 7     3.00
# 8     2.30
# 9     2.30
# 10    3.00
# 11    2.30
# 12    3.00
# 13    2.30
# 14    2.30
# 15    3.20
# 16    3.20
# 17    1.72
# 18    1.72
# 19    1.72
# 20    1.72
# 21    1.72
# 22    1.72
# 23    1.72
# 24    1.72
# 25    1.72
# 26    1.72
# 27    1.72
# 28    1.72
# 29    1.72
# 30    1.72
# 31    1.72
# 32    1.60
# 33    1.60
# 34    1.60
# 35    1.30
# 36    1.58
# 37    1.58
# Name: Engine HP, dtype: float64

# %%
df['Year'] >= 2015
# Out:
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32     True
# 33     True
# 34     True
# 35    False
# 36    False
# 37    False
# Name: Year, dtype: bool

# %%
df[df['Year'] >= 2015]
# Out:
#     Make       Model  Year                Engine Fuel Type  Engine HP  \
# 32  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 33  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
# 34  FIAT  124 Spider  2017  premium unleaded (recommended)      160.0
#
#     Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 32               4.0            MANUAL  rear wheel drive              2.0
# 33               4.0            MANUAL  rear wheel drive              2.0
# 34               4.0            MANUAL  rear wheel drive              2.0
#
#    Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 32     Performance      Compact   Convertible           35        26
# 33     Performance      Compact   Convertible           35        26
# 34     Performance      Compact   Convertible           35        26
#
#     Popularity   MSRP
# 32         819  27495
# 33         819  24995
# 34         819  28195

# %%
df[df.Make == 'BMW']
# Out:
#    Make     Model  Year             Engine Fuel Type  Engine HP  \
# 2   BMW  1 Series  2011  premium unleaded (required)      300.0
# 3   BMW  1 Series  2011  premium unleaded (required)      230.0
# 4   BMW  1 Series  2011  premium unleaded (required)      230.0
# 5   BMW  1 Series  2012  premium unleaded (required)      230.0
# 6   BMW  1 Series  2012  premium unleaded (required)      300.0
# 7   BMW  1 Series  2012  premium unleaded (required)      300.0
# 8   BMW  1 Series  2012  premium unleaded (required)      230.0
# 9   BMW  1 Series  2013  premium unleaded (required)      230.0
# 10  BMW  1 Series  2013  premium unleaded (required)      300.0
# 11  BMW  1 Series  2013  premium unleaded (required)      230.0
# 12  BMW  1 Series  2013  premium unleaded (required)      300.0
# 13  BMW  1 Series  2013  premium unleaded (required)      230.0
# 14  BMW  1 Series  2013  premium unleaded (required)      230.0
# 15  BMW  1 Series  2013  premium unleaded (required)      320.0
# ...

# %%
# to combine multiple conditions
df[(df['Make'] == 'BMW') & (df['Year'] > 2012)]
# Out:
#    Make     Model  Year             Engine Fuel Type  Engine HP  \
# 9   BMW  1 Series  2013  premium unleaded (required)      230.0
# 10  BMW  1 Series  2013  premium unleaded (required)      300.0
# 11  BMW  1 Series  2013  premium unleaded (required)      230.0
# 12  BMW  1 Series  2013  premium unleaded (required)      300.0
# 13  BMW  1 Series  2013  premium unleaded (required)      230.0
# 14  BMW  1 Series  2013  premium unleaded (required)      230.0
# 15  BMW  1 Series  2013  premium unleaded (required)      320.0
# 16  BMW  1 Series  2013  premium unleaded (required)      320.0
#
#     Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 9                6.0            MANUAL  rear wheel drive              2.0
# 10               6.0            MANUAL  rear wheel drive              2.0
# 11               6.0            MANUAL  rear wheel drive              2.0
# 12               6.0            MANUAL  rear wheel drive              2.0
# ...

# %% [markdown]
# # String Operations

# %%
df.Make.str.lower()
# Out:
# 2               bmw
# 3               bmw
# 4               bmw
# 5               bmw
# 6               bmw
# 7               bmw
# 8               bmw
# 9               bmw
# 10              bmw
# 11              bmw
# 12              bmw
# 13              bmw
# 14              bmw
# 15              bmw
# 16              bmw
# 17             audi
# 18             audi
# 19             audi
# 20             audi
# 21             audi
# 22             audi
# 23             audi
# 24             audi
# 25             audi
# 26             audi
# 27             audi
# 28             audi
# 29             audi
# 30             audi
# 31             audi
# 32             fiat
# 33             fiat
# 34             fiat
# 35    mercedes-benz
# 36    mercedes-benz
# 37    mercedes-benz
# Name: Make, dtype: object

# %%
df['Driven_Wheels'].replace(' ', '_')
# Out:
# 2      rear wheel drive
# 3      rear wheel drive
# 4      rear wheel drive
# 5      rear wheel drive
# 6      rear wheel drive
# 7      rear wheel drive
# 8      rear wheel drive
# 9      rear wheel drive
# 10     rear wheel drive
# 11     rear wheel drive
# 12     rear wheel drive
# 13     rear wheel drive
# 14     rear wheel drive
# 15     rear wheel drive
# 16     rear wheel drive
# 17    front wheel drive
# 18    front wheel drive
# 19      all wheel drive
# 20    front wheel drive
# 21      all wheel drive
# 22    front wheel drive
# 23      all wheel drive
# 24    front wheel drive
# 25    front wheel drive
# 26      all wheel drive
# 27    front wheel drive
# 28      all wheel drive
# 29    front wheel drive
# 30    front wheel drive
# 31      all wheel drive
# 32     rear wheel drive
# 33     rear wheel drive
# 34     rear wheel drive
# 35     rear wheel drive
# 36     rear wheel drive
# 37     rear wheel drive
# Name: Driven_Wheels, dtype: object

# %%
df['Market Category'] = df['Market Category'].str.lower().str.replace('-', '_')

# %% [markdown]
# # Summarizing operations

# %%
df.MSRP.max()
# Out:
# 48250

# %%
df.MSRP.min()
# Out:
# 2000

# %%
df.MSRP.mean()
# Out:
# 18935.694444444445

# %%
df.MSRP.describe()
# Out:
# count       36.000000
# mean     18935.694444
# std      17775.660894
# min       2000.000000
# 25%       2000.000000
# 50%      13497.500000
# 75%      36487.500000
# max      48250.000000
# Name: MSRP, dtype: float64

# %%
df.describe().round(2)
# for all numerical values
# Out:
#           Year  Engine HP  Engine Cylinders  Number of Doors  highway MPG  \
# count    36.00      36.00             36.00            36.00        36.00
# mean   2002.92     207.94              5.78             3.00        25.81
# std      10.45      55.73              0.64             1.01         3.92
# min    1991.00     130.00              4.00             2.00        20.00
# 25%    1993.00     172.00              6.00             2.00        23.50
# 50%    2002.50     172.00              6.00             3.00        25.50
# 75%    2013.00     230.00              6.00             4.00        28.00
# max    2017.00     320.00              6.00             4.00        35.00
#
#        city mpg  Popularity      MSRP
# count     36.00       36.00     36.00
# mean      18.28     3045.08  18935.69
# std        2.68     1121.02  17775.66
# min       16.00      617.00   2000.00
# 25%       17.00     3105.00   2000.00
# 50%       17.50     3105.00  13497.50
# ...

# %%
df.Make.value_counts()
# Out:
# Audi             15
# BMW              15
# Mercedes-Benz     3
# FIAT              3
# Name: Make, dtype: int64

# %%
# to get how many unique columns are there
df.Make.nunique()
# Out:
# 4

# %%
df.nunique()
# Out:
# Make                  4
# Model                 4
# Year                  8
# Engine Fuel Type      3
# Engine HP             7
# Engine Cylinders      2
# Transmission Type     2
# Driven_Wheels         3
# Number of Doors       2
# Market Category       4
# Vehicle Size          2
# Vehicle Style         4
# highway MPG           9
# city mpg              6
# Popularity            4
# MSRP                 17
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.fillna(0)
# Out:
#              Make       Model  Year                Engine Fuel Type  \
# 2             BMW    1 Series  2011     premium unleaded (required)
# 3             BMW    1 Series  2011     premium unleaded (required)
# 4             BMW    1 Series  2011     premium unleaded (required)
# 5             BMW    1 Series  2012     premium unleaded (required)
# 6             BMW    1 Series  2012     premium unleaded (required)
# 7             BMW    1 Series  2012     premium unleaded (required)
# 8             BMW    1 Series  2012     premium unleaded (required)
# 9             BMW    1 Series  2013     premium unleaded (required)
# 10            BMW    1 Series  2013     premium unleaded (required)
# 11            BMW    1 Series  2013     premium unleaded (required)
# 12            BMW    1 Series  2013     premium unleaded (required)
# 13            BMW    1 Series  2013     premium unleaded (required)
# 14            BMW    1 Series  2013     premium unleaded (required)
# ...

# %% [markdown]
# # Grouping

# %%
'''
SELECT
    transmission_type,
    AVG(MSRP)
FROM cars
group by transmission_type
'''

df.groupby('Transmission Type').MSRP.max()
# Out:
# Transmission Type
# AUTOMATIC     2000
# MANUAL       48250
# Name: MSRP, dtype: int64

# %%
df.groupby('Make').MSRP.mean()
# Out:
# Make
# Audi              2000.000000
# BMW              37666.666667
# FIAT             26895.000000
# Mercedes-Benz     2000.000000
# Name: MSRP, dtype: float64

# %% [markdown]
# # Numpy arrays

# %%
df['Make'].values
# Out:
# array(['BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'BMW',
#        'BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'BMW', 'Audi', 'Audi', 'Audi',
#        'Audi', 'Audi', 'Audi', 'Audi', 'Audi', 'Audi', 'Audi', 'Audi',
#        'Audi', 'Audi', 'Audi', 'Audi', 'FIAT', 'FIAT', 'FIAT',
#        'Mercedes-Benz', 'Mercedes-Benz', 'Mercedes-Benz'], dtype=object)

# %%
df.to_dict(orient='records')
# Out:
# [{'Make': 'BMW',
#   'Model': '1 Series',
#   'Year': 2011,
#   'Engine Fuel Type': 'premium unleaded (required)',
#   'Engine HP': 300.0,
#   'Engine Cylinders': 6.0,
#   'Transmission Type': 'MANUAL',
#   'Driven_Wheels': 'rear wheel drive',
#   'Number of Doors': 2.0,
#   'Market Category': 'luxury,high_performance',
#   'Vehicle Size': 'Compact',
#   'Vehicle Style': 'Coupe',
#   'highway MPG': 28,
#   'city mpg': 20,
#   'Popularity': 3916,
#   'MSRP': 36350},
#  {'Make': 'BMW',
#   'Model': '1 Series',
#   'Year': 2011,
#   'Engine Fuel Type': 'premium unleaded (required)',
#   'Engine HP': 230.0,
#   'Engine Cylinders': 6.0,
#   'Transmission Type': 'MANUAL',
#   'Driven_Wheels': 'rear wheel drive',
#   'Number of Doors': 2.0,
#   'Market Category': 'luxury,performance',
#   'Vehicle Size': 'Compact',
#   'Vehicle Style': 'Coupe',
#   'highway MPG': 28,
#   'city mpg': 18,
#   'Popularity': 3916,
#   'MSRP': 29450},
#  {'Make': 'BMW',
#   'Model': '1 Series',
# ...
